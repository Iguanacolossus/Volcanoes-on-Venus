# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv('volcanoe-data/volcanoes_train/train_images.csv',header= None)
y = pd.read_csv('volcanoe-data/volcanoes_train/train_labels.csv')

# %%
# going to use the tpe column as my target. I will change nans to 5.
y = y['Type']

# %%
y = y.fillna(5.0)

# %%
plt.hist(y)
plt.title('Target Distributon')
plt.savefig('images/reg_targ_dist.png')
#Type : 1= defin itely a volcano,2 =probably, 3= possibly, 4= onlya pit is visible ,5 no volcano
#maybe change this to a --o-- plot connecting the tops

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, MaxPool2D, Dropout

# %%
#normalizing image
Xtrain =  X/256
ytrain = y

# %%
img_rows, img_cols = 110, 110

X = Xtrain.values.reshape((-1, img_rows, img_cols, 1))
y = ytrain.values
X_train, X_vali, y_train, y_vali = train_test_split(X, y, test_size = 0.2, random_state = 666)

# %%
# keeping my model3 almost the same but change my final activation function  to linear and change loss to and metrics acordngly

modelCNN4 = Sequential()
modelCNN4.add(Conv2D(6, kernel_size = (3,3), activation = 'relu', input_shape = (img_rows, img_cols, 1)))
modelCNN4.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNN4.add(Dropout(0.5))
modelCNN4.add(Conv2D(12, kernel_size = (3,3), activation = 'relu'))
modelCNN4.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNN4.add(Dropout(0.5))
modelCNN4.add(Flatten())
modelCNN4.add(Dense(12,activation = 'relu'))
modelCNN4.add(Dense(1, activation = 'linear'))

# %%
modelCNN4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 108, 108, 6)       60
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 54, 54, 6)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 54, 54, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 52, 52, 12)        660
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 12)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 26, 26, 12)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8112)              0
# _________________________________________________________________
# dense (Dense)                (None, 12)                97356
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 98,089
# Trainable params: 98,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelCNN4.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
epochs =5
batch_size = 32

# %%
history4 = modelCNN4.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/15
# 175/175 [==============================] - 14s 82ms/step - loss: 1.2484 - mean_squared_error: 1.2484 - val_loss: 13.4263 - val_mean_squared_error: 13.4263
# Epoch 2/15
# 175/175 [==============================] - 17s 99ms/step - loss: 0.7223 - mean_squared_error: 0.7223 - val_loss: 12.9659 - val_mean_squared_error: 12.9659
# Epoch 3/15
# 175/175 [==============================] - 18s 105ms/step - loss: 0.7296 - mean_squared_error: 0.7296 - val_loss: 10.2205 - val_mean_squared_error: 10.2205
# Epoch 4/15
# 175/175 [==============================] - 17s 100ms/step - loss: 0.7158 - mean_squared_error: 0.7158 - val_loss: 9.1657 - val_mean_squared_error: 9.1657
# Epoch 5/15
# 175/175 [==============================] - 17s 99ms/step - loss: 0.6781 - mean_squared_error: 0.6781 - val_loss: 7.7724 - val_mean_squared_error: 7.7724
# Epoch 6/15
# 175/175 [==============================] - 22s 123ms/step - loss: 0.6507 - mean_squared_error: 0.6507 - val_loss: 7.7214 - val_mean_squared_error: 7.7214
# Epoch 7/15
# 175/175 [==============================] - 20s 116ms/step - loss: 0.6452 - mean_squared_error: 0.6452 - val_loss: 6.0983 - val_mean_squared_error: 6.0983
# Epoch 8/15
# 175/175 [==============================] - 18s 105ms/step - loss: 0.6210 - mean_squared_error: 0.6210 - val_loss: 5.9393 - val_mean_squared_error: 5.9393
# Epoch 9/15
# 175/175 [==============================] - 18s 104ms/step - loss: 0.6067 - mean_squared_error: 0.6067 - val_loss: 3.2652 - val_mean_squared_error: 3.2652
# Epoch 10/15
# 175/175 [==============================] - 19s 109ms/step - loss: 0.5855 - mean_squared_error: 0.5855 - val_loss: 2.7491 - val_mean_squared_error: 2.7491
# Epoch 11/15
# 175/175 [==============================] - 21s 121ms/step - loss: 0.5556 - mean_squared_error: 0.5556 - val_loss: 2.1270 - val_mean_squared_error: 2.1270
# Epoch 12/15
# 175/175 [==============================] - 19s 110ms/step - loss: 0.5148 - mean_squared_error: 0.5148 - val_loss: 1.6891 - val_mean_squared_error: 1.6891
# Epoch 13/15
# 175/175 [==============================] - 18s 103ms/step - loss: 0.5275 - mean_squared_error: 0.5275 - val_loss: 1.0314 - val_mean_squared_error: 1.0314
# Epoch 14/15
# 175/175 [==============================] - 19s 108ms/step - loss: 0.5031 - mean_squared_error: 0.5031 - val_loss: 0.8910 - val_mean_squared_error: 0.8910
# Epoch 15/15
# 175/175 [==============================] - 19s 109ms/step - loss: 0.5112 - mean_squared_error: 0.5112 - val_loss: 1.3188 - val_mean_squared_error: 1.3188

# %%
modelCNN4.save("reg_model.h5")

# %%
def lr_plot(history_obj,model_name):
    ''' input : model , model_name : tf model, str'''
    history = history_obj.history
    x_arr = np.arange(len(history['loss']))+1
    fig = plt.figure(figsize=(12,4))
    ax= fig.add_subplot(1,2,1)
    ax.plot(x_arr,history['loss'],'-o',label='train loss')
    ax.plot(x_arr,history['val_loss'],'--<',label='validation loss')
    ax.legend()
    ax.set_xlabel('Epoch',size=15)
    ax.set_ylabel('Loss',size=15)
    plt.grid()

    ax = fig.add_subplot(1,2,2)
    ax.plot(x_arr,history['mean_squared_error'],'--o',label='train MSE')
    ax.plot(x_arr,history['val_mean_squared_error'],'-->',label='val MSE')
    ax.legend()
    ax.set_xlabel('Epochs',size=15)
    ax.set_ylabel('Score',size=15)
    fig.suptitle(model_name,fontsize='16')
    plt.grid()
    plt.savefig('/home/rachel/Galvanize/capstone2/Cap2-repo/images/lr_plot_radiusCNN5_200.png')
#lr_plot(history4,'CNN 4 : Loss and MSE')

# %%
history4_obj = history4.history

# %%
pred = modelCNN4(X_vali)

# %%
plt.hist(y_vali,alpha=.7,label='True')
plt.hist(pred.numpy(),alpha=.7, label='predicted')
plt.legend()
plt.title('Predicting Confidance of Volcano Label')
plt.axvline(np.average(y_vali));

# %%
plt.scatter(list(range(len(res))),np.sqrt(res**2),alpha=.5)

# %%
plt.scatter(y_vali,np.sqrt(res**2),alpha=.5)

# %%
pred_flat = pred.numpy().flatten()

# %%
res = y_vali - pred_flat

# %%
#plt.scatter(list(range(len(res))),res)
plt.scatter(list(range(len(res))),y_vali,label='true',alpha=.5)
plt.scatter(list(range(len(res))),pred_flat,marker='s',label='pred',color='orange',alpha=.5)

# %%
plt.scatter(pred_flat, y_vali)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_vali,pred_flat)
# Out:
# -1.0236854450513886

# %%
y_vali
# Out:
# array([5., 5., 5., ..., 5., 5., 5.])

# %%
pred_flat
# Out:
# array([4.2162523, 3.7464535, 3.898248 , ..., 3.460461 , 4.404419 ,
#        3.3781564], dtype=float32)

# %% [markdown]
# this model sucks lets try to predict the radius of a volcano

# %%
X = pd.read_csv('volcanoe-data/volcanoes_train/train_images.csv',header= None)

# %%
y = pd.read_csv('volcanoe-data/volcanoes_train/train_labels.csv')

# %%
plt.hist(y['Radius'][y['Radius'].notnull()],bins=100)
plt.xlabel('True Radius',fontsize=12)
plt.ylabel('Frequency',fontsize=12)
plt.title('Histogram of Vocano Sizes',fontsize = 16)
plt.savefig('images/radius_hist.png')
;
# Out:
# ''

# %%
plt.scatter(y[y['Radius'].notnull()].index.values,y['Radius'][y['Radius'].notnull()])

# %%
X_rad = X[y['Radius'].notnull()]

# %%
y_rad = y[y['Radius'].notnull()]['Radius']

# %%
#normalizing image
X_rad =  X_rad/256

# %%
X_rad.shape
# Out:
# (1000, 12100)

# %%
y_rad.shape
# Out:
# (1000,)

# %%
img_rows, img_cols = 110, 110

X = X_rad.values.reshape((-1, img_rows, img_cols, 1))
y = y_rad.values
X_train, X_vali, y_train, y_vali = train_test_split(X, y, test_size = 0.2, random_state = 666)

# %%
modelCNNr = Sequential()
modelCNNr.add(Conv2D(6, kernel_size = (3,3), activation = 'relu', input_shape = (img_rows, img_cols, 1)))
modelCNNr.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNNr.add(Dropout(0.5))
modelCNNr.add(Conv2D(12, kernel_size = (3,3), activation = 'relu'))
modelCNNr.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNNr.add(Dropout(0.5))
modelCNNr.add(Flatten())
modelCNNr.add(Dense(12,activation = 'relu'))
modelCNNr.add(Dense(1, activation = 'linear'))

# %%
modelCNNr.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
historyr = modelCNN4.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/15
# 25/25 [==============================] - 2s 66ms/step - loss: 148.1192 - mean_squared_error: 148.1192 - val_loss: 188.7632 - val_mean_squared_error: 188.7632
# Epoch 2/15
# 25/25 [==============================] - 2s 65ms/step - loss: 130.4799 - mean_squared_error: 130.4799 - val_loss: 180.4978 - val_mean_squared_error: 180.4978
# Epoch 3/15
# 25/25 [==============================] - 2s 65ms/step - loss: 132.5310 - mean_squared_error: 132.5310 - val_loss: 191.2693 - val_mean_squared_error: 191.2693
# Epoch 4/15
# 25/25 [==============================] - 2s 67ms/step - loss: 130.9945 - mean_squared_error: 130.9945 - val_loss: 165.9967 - val_mean_squared_error: 165.9967
# Epoch 5/15
# 25/25 [==============================] - 2s 68ms/step - loss: 136.3562 - mean_squared_error: 136.3562 - val_loss: 168.2857 - val_mean_squared_error: 168.2857
# Epoch 6/15
# 25/25 [==============================] - 2s 69ms/step - loss: 130.8987 - mean_squared_error: 130.8987 - val_loss: 178.2674 - val_mean_squared_error: 178.2674
# Epoch 7/15
# 25/25 [==============================] - 2s 70ms/step - loss: 129.4445 - mean_squared_error: 129.4445 - val_loss: 173.6857 - val_mean_squared_error: 173.6857
# Epoch 8/15
# 25/25 [==============================] - 2s 72ms/step - loss: 128.1640 - mean_squared_error: 128.1640 - val_loss: 178.8407 - val_mean_squared_error: 178.8407
# Epoch 9/15
# 25/25 [==============================] - 2s 73ms/step - loss: 129.1370 - mean_squared_error: 129.1370 - val_loss: 179.7476 - val_mean_squared_error: 179.7476
# Epoch 10/15
# 25/25 [==============================] - 2s 74ms/step - loss: 128.9229 - mean_squared_error: 128.9229 - val_loss: 176.2229 - val_mean_squared_error: 176.2229
# Epoch 11/15
# 25/25 [==============================] - 2s 75ms/step - loss: 130.1772 - mean_squared_error: 130.1772 - val_loss: 192.2164 - val_mean_squared_error: 192.2164
# Epoch 12/15
# 25/25 [==============================] - 2s 76ms/step - loss: 132.0168 - mean_squared_error: 132.0168 - val_loss: 184.1185 - val_mean_squared_error: 184.1185
# Epoch 13/15
# 25/25 [==============================] - 2s 76ms/step - loss: 129.9055 - mean_squared_error: 129.9055 - val_loss: 181.0576 - val_mean_squared_error: 181.0576
# Epoch 14/15
# 25/25 [==============================] - 2s 85ms/step - loss: 126.3289 - mean_squared_error: 126.3289 - val_loss: 189.7307 - val_mean_squared_error: 189.7307
# Epoch 15/15
# 25/25 [==============================] - 2s 80ms/step - loss: 129.9037 - mean_squared_error: 129.9037 - val_loss: 181.9796 - val_mean_squared_error: 181.9796

# %%
lr_plot(historyr,'CNN radius : Loss and MSE')

# %%
historyr2 = modelCNN4.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/15
# 25/25 [==============================] - 2s 65ms/step - loss: 128.3913 - mean_squared_error: 128.3913 - val_loss: 180.7825 - val_mean_squared_error: 180.7825
# Epoch 2/15
# 25/25 [==============================] - 2s 64ms/step - loss: 128.6646 - mean_squared_error: 128.6646 - val_loss: 176.3884 - val_mean_squared_error: 176.3884
# Epoch 3/15
# 25/25 [==============================] - 2s 65ms/step - loss: 130.7187 - mean_squared_error: 130.7187 - val_loss: 167.3208 - val_mean_squared_error: 167.3208
# Epoch 4/15
# 25/25 [==============================] - 2s 65ms/step - loss: 129.5936 - mean_squared_error: 129.5936 - val_loss: 165.8734 - val_mean_squared_error: 165.8734
# Epoch 5/15
# 25/25 [==============================] - 2s 66ms/step - loss: 129.1440 - mean_squared_error: 129.1440 - val_loss: 171.8124 - val_mean_squared_error: 171.8124
# Epoch 6/15
# 25/25 [==============================] - 2s 70ms/step - loss: 127.7292 - mean_squared_error: 127.7292 - val_loss: 173.0601 - val_mean_squared_error: 173.0601
# Epoch 7/15
# 25/25 [==============================] - 2s 69ms/step - loss: 125.9292 - mean_squared_error: 125.9292 - val_loss: 172.6918 - val_mean_squared_error: 172.6918
# Epoch 8/15
# 25/25 [==============================] - 2s 70ms/step - loss: 126.5237 - mean_squared_error: 126.5237 - val_loss: 174.2143 - val_mean_squared_error: 174.2143
# Epoch 9/15
# 25/25 [==============================] - 2s 72ms/step - loss: 127.9753 - mean_squared_error: 127.9753 - val_loss: 168.9107 - val_mean_squared_error: 168.9107
# 25/25 [==============================] - 2s 74ms/step - loss: 127.4604 - mean_squared_error: 127.4604 - val_loss: 173.6360 - val_mean_squared_error: 173.6360
# Epoch 12/15
# 25/25 [==============================] - 2s 86ms/step - loss: 123.2603 - mean_squared_error: 123.2603 - val_loss: 166.4651 - val_mean_squared_error: 166.4651
# Epoch 13/15
# 25/25 [==============================] - 2s 81ms/step - loss: 124.8367 - mean_squared_error: 124.8367 - val_loss: 169.2997 - val_mean_squared_error: 169.2997
# Epoch 14/15
# 25/25 [==============================] - 2s 79ms/step - loss: 122.7338 - mean_squared_error: 122.7338 - val_loss: 173.6889 - val_mean_squared_error: 173.6889
# Epoch 15/15
# 25/25 [==============================] - 2s 81ms/step - loss: 123.2710 - mean_squared_error: 123.2710 - val_loss: 168.0511 - val_mean_squared_error: 168.0511

# %%
lr_plot(historyr3,'CNN radius 45 epochs: Loss and MSE')

# %%
#lets see what the whole learning curve would look like
historyr_45 = historyr.history['val_mean_squared_error']
historyr_45.extend(historyr2.history['val_mean_squared_error'])
historyr_45.extend(historyr3.history['val_mean_squared_error'])

# %%
plt.plot(list(range(45)),np.sqrt(historyr_45),'--o',color='purple')
plt.xlabel('Epochs',fontsize=12)
plt.ylabel('RMSE',fontsize=12)
plt.title('Validation RMSE of CNN-radius',fontsize=16)
plt.savefig('images/cnnr_45.png')

# %%
modelCNNr.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 108, 108, 6)       60
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 54, 54, 6)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 54, 54, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 12)        660
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 26, 26, 12)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 26, 26, 12)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8112)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                97356
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 98,089
# Trainable params: 98,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelCNNr.save("radius_model.h5")

# %%
13**.5
# Out:
# 3.605551275463989

# %%
# let try some augmentations
X_train.shape
# Out:
# (800, 110, 110, 1)

# %%
X_train[0].reshape(110,110).shape
# Out:
# (110, 110)

# %%
plt.imshow(X_train[0].reshape(110,110))
plt.title(f'Radius = {y_train[0]}')
# Out:
# Text(0.5, 1.0, 'Radius = 30.81')

# %%
#flip horazontaly
im = X_train[0]
imflipped = tf.image.flip_left_right(im)
plt.imshow(imflipped.numpy().reshape(110,110))
plt.title(f'flipped horazontaly')
# Out:
# Text(0.5, 1.0, 'flipped horazontaly')

# %%
def augment_plot(X_train, idx):
    im = X_train[idx]
    im_lr= tf.image.random_flip_left_right(im)
    im_ud = tf.image.random_flip_up_down(im)
    im_crop = tf.image.random_crop(im,size=(95,95,1))
    im_crop = tf.image.resize(im_crop,size=(110,110))
    
    fig, axs = plt.subplots(1,4,figsize=(10,10))
    #fig.suptitle('Augmentation Example')

    for ax in axs:
        ax.set_xticks([])
        ax.set_yticks([])
    
    axs.flatten()[0].imshow(im.reshape(110,110))
    axs.flatten()[0].set_title('original')
    axs.flatten()[1].imshow(im_lr.numpy().reshape(110,110))
    axs.flatten()[1].set_title('rand. left or right')
    axs.flatten()[2].imshow(im_ud.numpy().reshape(110,110))
    axs.flatten()[2].set_title('rand. up or down')
    axs.flatten()[3].imshow(im_crop.numpy().reshape(110,110))
    axs.flatten()[3].set_title('random crop') 
    plt.tight_layout()
   # plt.savefig('images/aug_examples.png')

# %%
augment_plot(X_train,0)

# %%
def augmentation(X,y):
    for i, im in enumer
# Out:
#   File "<ipython-input-299-1345be4810f6>", line 2
#     for i, im in enumer
#                        ^
# SyntaxError: invalid syntax

# %%
X_train.shape
# Out:
# (800, 110, 110, 1)

# %%
prac_sample = X_train[[3,7,4,9,1]]

# %%
prac_sample.shape
# Out:
# (5, 110, 110, 1)

# %%
pc= prac_sample
def augment1(tensor_im):
    '''intout: 3 d tensor image'''
    
    im = tensor_im
    if np.random.random() > .5:
        im = tf.image.random_flip_left_right(im)
    #if np.random.random() > .5:
    #    im = tf.image.random_flip_up_down(im)
    #if np.random.random() > .5:
        #im_crop = tf.image.random_crop(im,size=(95,95,1))
       # im = tf.image.resize(im_crop,size=(110,110))
    
    #im_lr = tf.expand_dims(im_lr,axis=0)
    #im_ud = tf.expand_dims(im_ud,axis=0)
    #im_crop = tf.expand_dims(im_crop,axis=0)
    #im = tf.expand_dims(im, axis=0)
    
    #stack = tf.stack([im_lr,im_ud,im_crop],axis=0)
    return im

# %%
# batches of augented images and their labels
def train_generator(X_train,y_train,batch_size=4):
    '''take rand subset of x and its labels'''
    while True:
        idx = np.random.randint(0,len(X_train),size=batch_size)
        #X = np.vectorize(augment1)(X_train[idx])
        X = [augment1(x) for x in X_train[idx]]
        yield np.array(X), y_train[idx]

# %%
i,j = next(train_generator(X_train,y_train))

# %%
historyr32 = modelCNN4.fit(train_generator(X_train,y_train,batch_size=4), epochs=100, steps_per_epoch=200, 
                        validation_data=(X_vali, y_vali)
                       )
#historyr32 id the second pass at 200 epochs
# Out:
# Epoch 1/100
# 200/200 [==============================] - 4s 20ms/step - loss: 41.6155 - mean_squared_error: 41.6155 - val_loss: 134.7629 - val_mean_squared_error: 134.7629
# Epoch 2/100
# 200/200 [==============================] - 4s 21ms/step - loss: 40.6173 - mean_squared_error: 40.6173 - val_loss: 138.0725 - val_mean_squared_error: 138.0725
# Epoch 3/100
# 200/200 [==============================] - 4s 22ms/step - loss: 43.6424 - mean_squared_error: 43.6424 - val_loss: 128.4853 - val_mean_squared_error: 128.4853
# Epoch 4/100
# 200/200 [==============================] - 5s 25ms/step - loss: 35.9525 - mean_squared_error: 35.9525 - val_loss: 129.3947 - val_mean_squared_error: 129.3947
# Epoch 5/100
# 200/200 [==============================] - 5s 25ms/step - loss: 36.1602 - mean_squared_error: 36.1602 - val_loss: 132.8153 - val_mean_squared_error: 132.8153
# Epoch 6/100
# 200/200 [==============================] - 5s 26ms/step - loss: 43.5257 - mean_squared_error: 43.5257 - val_loss: 132.5229 - val_mean_squared_error: 132.5229
# Epoch 7/100
# 200/200 [==============================] - 5s 25ms/step - loss: 37.4873 - mean_squared_error: 37.4873 - val_loss: 156.5706 - val_mean_squared_error: 156.5706
# Epoch 8/100
# 200/200 [==============================] - 5s 25ms/step - loss: 35.9606 - mean_squared_error: 35.9606 - val_loss: 132.1298 - val_mean_squared_error: 132.1298
# Epoch 9/100
# 200/200 [==============================] - 4s 18ms/step - loss: 22.2785 - mean_squared_error: 22.2785 - val_loss: 144.5859 - val_mean_squared_error: 144.5859
# Epoch 100/100
# 200/200 [==============================] - 4s 18ms/step - loss: 20.4614 - mean_squared_error: 20.4614 - val_loss: 139.2393 - val_mean_squared_error: 139.2393

# %%
for k, v in historyr3.history.items():
    plt.plot(v,label=k)
plt.legend()

# %%
lr_plot(historyr3,'CNN radius: Loss and MSE (200)')

# %%
lr_plot(historyr32,'CNN radius: Loss and MSE (400)')

# %%
140**.5
# Out:
# 11.832159566199232

# %%
modelCNN4.save("radius_model.h5")

# %%
#
modelCNN5 = Sequential()
modelCNN5.add(Conv2D(6, kernel_size = (3,3), activation = 'relu', input_shape = (img_rows, img_cols, 1)))
modelCNN5.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNN5.add(Dropout(0.5))
modelCNN5.add(Conv2D(12, kernel_size = (3,3), activation = 'relu'))
modelCNN5.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNN5.add(Dropout(0.5))
modelCNN5.add(Conv2D(24, kernel_size = (3,3), activation = 'relu'))
modelCNN5.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNN5.add(Dropout(0.5))
modelCNN5.add(Flatten())
modelCNN5.add(Dense(12,activation = 'relu'))
modelCNN5.add(Dense(1, activation = 'linear'))

# %%
modelCNN5.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
modelCNN5.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 108, 108, 6)       60
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 54, 54, 6)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 54, 54, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 12)        660
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 26, 26, 12)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 26, 26, 12)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 24)        2616
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 24)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 24)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3456)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                41484
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 44,833
# Trainable params: 44,833
# Non-trainable params: 0
# _________________________________________________________________

# %%
historyr5 = modelCNN5.fit(train_generator(X_train,y_train,batch_size=4), epochs=200, steps_per_epoch=200, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/200
# 200/200 [==============================] - 3s 14ms/step - loss: 142.5363 - mean_squared_error: 142.5363 - val_loss: 258.7452 - val_mean_squared_error: 258.7452
# Epoch 2/200
# 200/200 [==============================] - 3s 14ms/step - loss: 129.8686 - mean_squared_error: 129.8686 - val_loss: 248.0783 - val_mean_squared_error: 248.0783
# Epoch 3/200
# 200/200 [==============================] - 3s 14ms/step - loss: 138.8214 - mean_squared_error: 138.8214 - val_loss: 256.1498 - val_mean_squared_error: 256.1498
# Epoch 4/200
# 200/200 [==============================] - 3s 15ms/step - loss: 136.0551 - mean_squared_error: 136.0551 - val_loss: 277.5061 - val_mean_squared_error: 277.5061
# Epoch 5/200
# 200/200 [==============================] - 3s 15ms/step - loss: 126.7065 - mean_squared_error: 126.7065 - val_loss: 241.6555 - val_mean_squared_error: 241.6555
# Epoch 6/200
# 200/200 [==============================] - 3s 15ms/step - loss: 126.7939 - mean_squared_error: 126.7939 - val_loss: 254.6496 - val_mean_squared_error: 254.6496
# Epoch 7/200
# 200/200 [==============================] - 3s 16ms/step - loss: 133.8784 - mean_squared_error: 133.8784 - val_loss: 225.8813 - val_mean_squared_error: 225.8813
# Epoch 8/200
# 200/200 [==============================] - 3s 17ms/step - loss: 135.5693 - mean_squared_error: 135.5693 - val_loss: 220.0210 - val_mean_squared_error: 220.0210
# Epoch 9/200
# 200/200 [==============================] - 4s 18ms/step - loss: 109.6074 - mean_squared_error: 109.6074 - val_loss: 155.8128 - val_mean_squared_error: 155.8128
# Epoch 187/200
# 200/200 [==============================] - 4s 20ms/step - loss: 116.3596 - mean_squared_error: 116.3596 - val_loss: 156.7699 - val_mean_squared_error: 156.7699
# Epoch 188/200
# 200/200 [==============================] - 3s 17ms/step - loss: 116.0630 - mean_squared_error: 116.0630 - val_loss: 154.5331 - val_mean_squared_error: 154.5331
# Epoch 189/200
# 200/200 [==============================] - 3s 16ms/step - loss: 95.1156 - mean_squared_error: 95.1156 - val_loss: 150.7781 - val_mean_squared_error: 150.7781
# Epoch 190/200
# 200/200 [==============================] - 3s 17ms/step - loss: 99.6607 - mean_squared_error: 99.6607 - val_loss: 157.7270 - val_mean_squared_error: 157.7270
# Epoch 191/200
# 200/200 [==============================] - 4s 18ms/step - loss: 97.8728 - mean_squared_error: 97.8728 - val_loss: 163.4766 - val_mean_squared_error: 163.4766
# Epoch 192/200
# 200/200 [==============================] - 4s 18ms/step - loss: 90.3505 - mean_squared_error: 90.3505 - val_loss: 149.8206 - val_mean_squared_error: 149.8206
# Epoch 193/200
# 200/200 [==============================] - 4s 19ms/step - loss: 103.6072 - mean_squared_error: 103.6072 - val_loss: 163.6690 - val_mean_squared_error: 163.6690
# Epoch 194/200
# 200/200 [==============================] - 3s 17ms/step - loss: 95.7789 - mean_squared_error: 95.7789 - val_loss: 152.5895 - val_mean_squared_error: 152.5895
# Epoch 195/200
# 200/200 [==============================] - 3s 17ms/step - loss: 80.2733 - mean_squared_error: 80.2733 - val_loss: 149.9952 - val_mean_squared_error: 149.9952
# Epoch 196/200
# 200/200 [==============================] - 3s 17ms/step - loss: 94.0935 - mean_squared_error: 94.0935 - val_loss: 157.3410 - val_mean_squared_error: 157.3410
# Epoch 197/200
# 200/200 [==============================] - 3s 16ms/step - loss: 99.6619 - mean_squared_error: 99.6619 - val_loss: 162.0410 - val_mean_squared_error: 162.0410
# Epoch 198/200
# 200/200 [==============================] - 3s 16ms/step - loss: 97.9121 - mean_squared_error: 97.9121 - val_loss: 153.4669 - val_mean_squared_error: 153.4669
# Epoch 199/200
# 200/200 [==============================] - 3s 16ms/step - loss: 82.7522 - mean_squared_error: 82.7522 - val_loss: 145.4710 - val_mean_squared_error: 145.4710
# Epoch 200/200
# 200/200 [==============================] - 4s 19ms/step - loss: 102.7569 - mean_squared_error: 102.7569 - val_loss: 145.7654 - val_mean_squared_error: 145.7654

# %%
lr_plot(historyr5,'CNN radius 2.0: Loss and MSE (200 epochs)')

# %%
historyr33 = modelCNN4.fit(train_generator(X_train,y_train,batch_size=4), epochs=1, steps_per_epoch=200, 
                        validation_data=(X_vali, y_vali)
                       )
#using the same model pre trained i train again with soe cropping on random images
# Out:
# 200/200 [==============================] - 659s 3s/step - loss: 67.6231 - mean_squared_error: 67.6231 - val_loss: 145.0037 - val_mean_squared_error: 145.0037

# %%
660/60
# Out:
# 11.0
