# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv('volcanoe-data/volcanoes_train/train_images.csv',header= None)
y = pd.read_csv('volcanoe-data/volcanoes_train/train_labels.csv')

# %%
# going to use the tpe column as my target. I will change nans to 5.
y = y['Type']

# %%
y = y.fillna(5.0)

# %%
plt.hist(y)
plt.title('Target Distributon')
plt.savefig('images/reg_targ_dist.png')
#Type : 1= defin itely a volcano,2 =probably, 3= possibly, 4= onlya pit is visible ,5 no volcano
#maybe change this to a --o-- plot connecting the tops

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, MaxPool2D, Dropout

# %%
#normalizing image
Xtrain =  X/256
ytrain = y

# %%
img_rows, img_cols = 110, 110

X = Xtrain.values.reshape((-1, img_rows, img_cols, 1))
y = ytrain.values
X_train, X_vali, y_train, y_vali = train_test_split(X, y, test_size = 0.2, random_state = 666)

# %%
# keeping my model3 almost the same but change my final activation function  to linear and change loss to and metrics acordngly

modelCNN4 = Sequential()
modelCNN4.add(Conv2D(6, kernel_size = (3,3), activation = 'relu', input_shape = (img_rows, img_cols, 1)))
modelCNN4.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNN4.add(Dropout(0.5))
modelCNN4.add(Conv2D(12, kernel_size = (3,3), activation = 'relu'))
modelCNN4.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNN4.add(Dropout(0.5))
modelCNN4.add(Flatten())
modelCNN4.add(Dense(12,activation = 'relu'))
modelCNN4.add(Dense(1, activation = 'linear'))

# %%
modelCNN4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 108, 108, 6)       60
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 54, 54, 6)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 54, 54, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 52, 52, 12)        660
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 12)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 26, 26, 12)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8112)              0
# _________________________________________________________________
# dense (Dense)                (None, 12)                97356
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 98,089
# Trainable params: 98,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelCNN4.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
epochs =15
batch_size = 32

# %%
history4 = modelCNN4.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/15
# 175/175 [==============================] - 14s 82ms/step - loss: 1.2484 - mean_squared_error: 1.2484 - val_loss: 13.4263 - val_mean_squared_error: 13.4263
# Epoch 2/15
# 175/175 [==============================] - 17s 99ms/step - loss: 0.7223 - mean_squared_error: 0.7223 - val_loss: 12.9659 - val_mean_squared_error: 12.9659
# Epoch 3/15
# 175/175 [==============================] - 18s 105ms/step - loss: 0.7296 - mean_squared_error: 0.7296 - val_loss: 10.2205 - val_mean_squared_error: 10.2205
# Epoch 4/15
# 175/175 [==============================] - 17s 100ms/step - loss: 0.7158 - mean_squared_error: 0.7158 - val_loss: 9.1657 - val_mean_squared_error: 9.1657
# Epoch 5/15
# 175/175 [==============================] - 17s 99ms/step - loss: 0.6781 - mean_squared_error: 0.6781 - val_loss: 7.7724 - val_mean_squared_error: 7.7724
# Epoch 6/15
# 175/175 [==============================] - 22s 123ms/step - loss: 0.6507 - mean_squared_error: 0.6507 - val_loss: 7.7214 - val_mean_squared_error: 7.7214
# Epoch 7/15
# 175/175 [==============================] - 20s 116ms/step - loss: 0.6452 - mean_squared_error: 0.6452 - val_loss: 6.0983 - val_mean_squared_error: 6.0983
# Epoch 8/15
# 175/175 [==============================] - 18s 105ms/step - loss: 0.6210 - mean_squared_error: 0.6210 - val_loss: 5.9393 - val_mean_squared_error: 5.9393
# Epoch 9/15
# 175/175 [==============================] - 18s 104ms/step - loss: 0.6067 - mean_squared_error: 0.6067 - val_loss: 3.2652 - val_mean_squared_error: 3.2652
# Epoch 10/15
# 175/175 [==============================] - 19s 109ms/step - loss: 0.5855 - mean_squared_error: 0.5855 - val_loss: 2.7491 - val_mean_squared_error: 2.7491
# Epoch 11/15
# 175/175 [==============================] - 21s 121ms/step - loss: 0.5556 - mean_squared_error: 0.5556 - val_loss: 2.1270 - val_mean_squared_error: 2.1270
# Epoch 12/15
# 175/175 [==============================] - 19s 110ms/step - loss: 0.5148 - mean_squared_error: 0.5148 - val_loss: 1.6891 - val_mean_squared_error: 1.6891
# Epoch 13/15
# 175/175 [==============================] - 18s 103ms/step - loss: 0.5275 - mean_squared_error: 0.5275 - val_loss: 1.0314 - val_mean_squared_error: 1.0314
# Epoch 14/15
# 175/175 [==============================] - 19s 108ms/step - loss: 0.5031 - mean_squared_error: 0.5031 - val_loss: 0.8910 - val_mean_squared_error: 0.8910
# Epoch 15/15
# 175/175 [==============================] - 19s 109ms/step - loss: 0.5112 - mean_squared_error: 0.5112 - val_loss: 1.3188 - val_mean_squared_error: 1.3188

# %%
modelCNN4.save("reg_model.h5")

# %%
def lr_plot(history_obj,model_name):
    ''' input : model , model_name : tf model, str'''
    history = history_obj.history
    x_arr = np.arange(len(history['loss']))+1
    fig = plt.figure(figsize=(12,4))
    ax= fig.add_subplot(1,2,1)
    ax.plot(x_arr,history['loss'],'-o',label='train loss')
    ax.plot(x_arr,history['val_loss'],'--<',label='validation loss')
    ax.legend()
    ax.set_xlabel('Epoch',size=15)
    ax.set_ylabel('Loss',size=15)

    ax = fig.add_subplot(1,2,2)
    ax.plot(x_arr,history['mean_squared_error'],'--o',label='train MSE')
    ax.plot(x_arr,history['val_mean_squared_error'],'-->',label='val MSE')
    ax.legend()
    ax.set_xlabel('Epochs',size=15)
    ax.set_ylabel('Score',size=15)
    fig.suptitle(model_name,fontsize='16')
    plt.savefig('/home/rachel/Galvanize/capstone2/Cap2-repo/images/lr_plot_reg.png')
lr_plot(history4,'CNN 4 : Loss and MSE')

# %%
history4_obj = history4.history

# %%
pred = modelCNN4(X_vali)

# %%
plt.hist(y_vali,alpha=.7,label='True')
plt.hist(pred.numpy(),alpha=.7, label='predicted')
plt.legend()
plt.title('Predicting Confidance of Volcano Label')
plt.axvline(np.average(y_vali));

# %%
plt.scatter(list(range(len(res))),np.sqrt(res**2),alpha=.5)

# %%
plt.scatter(y_vali,np.sqrt(res**2),alpha=.5)

# %%
pred_flat = pred.numpy().flatten()

# %%
res = y_vali - pred_flat

# %%
#plt.scatter(list(range(len(res))),res)
plt.scatter(list(range(len(res))),y_vali,label='true',alpha=.5)
plt.scatter(list(range(len(res))),pred_flat,marker='s',label='pred',color='orange',alpha=.5)

# %%
plt.scatter(pred_flat, y_vali)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_vali,pred_flat)
# Out:
# -1.0236854450513886

# %%
y_vali
# Out:
# array([5., 5., 5., ..., 5., 5., 5.])

# %%
pred_flat
# Out:
# array([4.2162523, 3.7464535, 3.898248 , ..., 3.460461 , 4.404419 ,
#        3.3781564], dtype=float32)

# %% [markdown]
# this model sucks lets try to predict the radius of a volcano

# %%
X = pd.read_csv('volcanoe-data/volcanoes_train/train_images.csv',header= None)

# %%
y = pd.read_csv('volcanoe-data/volcanoes_train/train_labels.csv')

# %%
plt.hist(y['Radius'][y['Radius'].notnull()],bins=100)
;
# Out:
# ''

# %%
plt.scatter(y[y['Radius'].notnull()].index.values,y['Radius'][y['Radius'].notnull()])

# %%
X_rad = X[y['Radius'].notnull()]

# %%
y_rad = y[y['Radius'].notnull()]['Radius']

# %%
#normalizing image
X_rad =  X_rad/256

# %%
X_rad.shape
# Out:
# (1000, 12100)

# %%
y_rad.shape
# Out:
# (1000,)

# %%
img_rows, img_cols = 110, 110

X = X_rad.values.reshape((-1, img_rows, img_cols, 1))
y = y_rad.values
X_train, X_vali, y_train, y_vali = train_test_split(X, y, test_size = 0.2, random_state = 666)

# %%
modelCNNr = Sequential()
modelCNNr.add(Conv2D(6, kernel_size = (3,3), activation = 'relu', input_shape = (img_rows, img_cols, 1)))
modelCNNr.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNNr.add(Dropout(0.5))
modelCNNr.add(Conv2D(12, kernel_size = (3,3), activation = 'relu'))
modelCNNr.add(MaxPool2D(pool_size=(2,2), strides=2))
modelCNNr.add(Dropout(0.5))
modelCNNr.add(Flatten())
modelCNNr.add(Dense(12,activation = 'relu'))
modelCNNr.add(Dense(1, activation = 'linear'))

# %%
modelCNNr.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
historyr = modelCNN4.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/15
# 25/25 [==============================] - 2s 66ms/step - loss: 148.1192 - mean_squared_error: 148.1192 - val_loss: 188.7632 - val_mean_squared_error: 188.7632
# Epoch 2/15
# 25/25 [==============================] - 2s 65ms/step - loss: 130.4799 - mean_squared_error: 130.4799 - val_loss: 180.4978 - val_mean_squared_error: 180.4978
# Epoch 3/15
# 25/25 [==============================] - 2s 65ms/step - loss: 132.5310 - mean_squared_error: 132.5310 - val_loss: 191.2693 - val_mean_squared_error: 191.2693
# Epoch 4/15
# 25/25 [==============================] - 2s 67ms/step - loss: 130.9945 - mean_squared_error: 130.9945 - val_loss: 165.9967 - val_mean_squared_error: 165.9967
# Epoch 5/15
# 25/25 [==============================] - 2s 68ms/step - loss: 136.3562 - mean_squared_error: 136.3562 - val_loss: 168.2857 - val_mean_squared_error: 168.2857
# Epoch 6/15
# 25/25 [==============================] - 2s 69ms/step - loss: 130.8987 - mean_squared_error: 130.8987 - val_loss: 178.2674 - val_mean_squared_error: 178.2674
# Epoch 7/15
# 25/25 [==============================] - 2s 70ms/step - loss: 129.4445 - mean_squared_error: 129.4445 - val_loss: 173.6857 - val_mean_squared_error: 173.6857
# Epoch 8/15
# 25/25 [==============================] - 2s 72ms/step - loss: 128.1640 - mean_squared_error: 128.1640 - val_loss: 178.8407 - val_mean_squared_error: 178.8407
# Epoch 9/15
# 25/25 [==============================] - 2s 73ms/step - loss: 129.1370 - mean_squared_error: 129.1370 - val_loss: 179.7476 - val_mean_squared_error: 179.7476
# Epoch 10/15
# 25/25 [==============================] - 2s 74ms/step - loss: 128.9229 - mean_squared_error: 128.9229 - val_loss: 176.2229 - val_mean_squared_error: 176.2229
# Epoch 11/15
# 25/25 [==============================] - 2s 75ms/step - loss: 130.1772 - mean_squared_error: 130.1772 - val_loss: 192.2164 - val_mean_squared_error: 192.2164
# Epoch 12/15
# 25/25 [==============================] - 2s 76ms/step - loss: 132.0168 - mean_squared_error: 132.0168 - val_loss: 184.1185 - val_mean_squared_error: 184.1185
# Epoch 13/15
# 25/25 [==============================] - 2s 76ms/step - loss: 129.9055 - mean_squared_error: 129.9055 - val_loss: 181.0576 - val_mean_squared_error: 181.0576
# Epoch 14/15
# 25/25 [==============================] - 2s 85ms/step - loss: 126.3289 - mean_squared_error: 126.3289 - val_loss: 189.7307 - val_mean_squared_error: 189.7307
# Epoch 15/15
# 25/25 [==============================] - 2s 80ms/step - loss: 129.9037 - mean_squared_error: 129.9037 - val_loss: 181.9796 - val_mean_squared_error: 181.9796

# %%
lr_plot(historyr,'CNN radius : Loss and MSE')

# %%
historyr2 = modelCNN4.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/15
# 25/25 [==============================] - 2s 65ms/step - loss: 128.3913 - mean_squared_error: 128.3913 - val_loss: 180.7825 - val_mean_squared_error: 180.7825
# Epoch 2/15
# 25/25 [==============================] - 2s 64ms/step - loss: 128.6646 - mean_squared_error: 128.6646 - val_loss: 176.3884 - val_mean_squared_error: 176.3884
# Epoch 3/15
# 25/25 [==============================] - 2s 65ms/step - loss: 130.7187 - mean_squared_error: 130.7187 - val_loss: 167.3208 - val_mean_squared_error: 167.3208
# Epoch 4/15
# 25/25 [==============================] - 2s 65ms/step - loss: 129.5936 - mean_squared_error: 129.5936 - val_loss: 165.8734 - val_mean_squared_error: 165.8734
# Epoch 5/15
# 25/25 [==============================] - 2s 66ms/step - loss: 129.1440 - mean_squared_error: 129.1440 - val_loss: 171.8124 - val_mean_squared_error: 171.8124
# Epoch 6/15
# 25/25 [==============================] - 2s 70ms/step - loss: 127.7292 - mean_squared_error: 127.7292 - val_loss: 173.0601 - val_mean_squared_error: 173.0601
# Epoch 7/15
# 25/25 [==============================] - 2s 69ms/step - loss: 125.9292 - mean_squared_error: 125.9292 - val_loss: 172.6918 - val_mean_squared_error: 172.6918
# Epoch 8/15
# 25/25 [==============================] - 2s 70ms/step - loss: 126.5237 - mean_squared_error: 126.5237 - val_loss: 174.2143 - val_mean_squared_error: 174.2143
# Epoch 9/15
# 25/25 [==============================] - 2s 72ms/step - loss: 127.9753 - mean_squared_error: 127.9753 - val_loss: 168.9107 - val_mean_squared_error: 168.9107
# Epoch 10/15
# 25/25 [==============================] - 2s 72ms/step - loss: 126.2216 - mean_squared_error: 126.2216 - val_loss: 177.1777 - val_mean_squared_error: 177.1777
# Epoch 11/15
# 25/25 [==============================] - 2s 73ms/step - loss: 126.0934 - mean_squared_error: 126.0934 - val_loss: 171.6247 - val_mean_squared_error: 171.6247
# Epoch 12/15
# 25/25 [==============================] - 2s 85ms/step - loss: 127.3170 - mean_squared_error: 127.3170 - val_loss: 180.4751 - val_mean_squared_error: 180.4751
# Epoch 13/15
# 25/25 [==============================] - 2s 81ms/step - loss: 125.8022 - mean_squared_error: 125.8022 - val_loss: 173.4507 - val_mean_squared_error: 173.4507
# Epoch 14/15
# 25/25 [==============================] - 2s 81ms/step - loss: 126.5429 - mean_squared_error: 126.5429 - val_loss: 183.1523 - val_mean_squared_error: 183.1523
# Epoch 15/15
# 25/25 [==============================] - 2s 81ms/step - loss: 126.1686 - mean_squared_error: 126.1686 - val_loss: 178.2437 - val_mean_squared_error: 178.2437

# %%
lr_plot(historyr2,'CNN radius 15 more epochs: Loss and MSE')

# %%
historyr3 = modelCNN4.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(X_vali, y_vali)
                       )
# Out:
# Epoch 1/15
# 25/25 [==============================] - 2s 64ms/step - loss: 125.5726 - mean_squared_error: 125.5726 - val_loss: 170.6888 - val_mean_squared_error: 170.6888
# Epoch 2/15
# 25/25 [==============================] - 2s 65ms/step - loss: 126.1092 - mean_squared_error: 126.1092 - val_loss: 184.1973 - val_mean_squared_error: 184.1973
# Epoch 3/15
# 25/25 [==============================] - 2s 64ms/step - loss: 128.1809 - mean_squared_error: 128.1809 - val_loss: 168.5403 - val_mean_squared_error: 168.5403
# Epoch 4/15
# 25/25 [==============================] - 2s 66ms/step - loss: 126.0566 - mean_squared_error: 126.0566 - val_loss: 176.7704 - val_mean_squared_error: 176.7704
# Epoch 5/15
# 25/25 [==============================] - 2s 68ms/step - loss: 125.7291 - mean_squared_error: 125.7291 - val_loss: 174.0348 - val_mean_squared_error: 174.0348
# Epoch 6/15
# 25/25 [==============================] - 2s 68ms/step - loss: 126.9997 - mean_squared_error: 126.9997 - val_loss: 165.3046 - val_mean_squared_error: 165.3046
# Epoch 7/15
# 25/25 [==============================] - 2s 70ms/step - loss: 126.3204 - mean_squared_error: 126.3204 - val_loss: 165.8301 - val_mean_squared_error: 165.8301
# Epoch 8/15
# 25/25 [==============================] - 2s 71ms/step - loss: 125.0211 - mean_squared_error: 125.0211 - val_loss: 176.1470 - val_mean_squared_error: 176.1470
# Epoch 9/15
# 25/25 [==============================] - 2s 72ms/step - loss: 125.0625 - mean_squared_error: 125.0625 - val_loss: 166.5058 - val_mean_squared_error: 166.5058
# Epoch 10/15
# 25/25 [==============================] - 2s 73ms/step - loss: 123.9193 - mean_squared_error: 123.9193 - val_loss: 166.9553 - val_mean_squared_error: 166.9553
# Epoch 11/15
# 25/25 [==============================] - 2s 74ms/step - loss: 127.4604 - mean_squared_error: 127.4604 - val_loss: 173.6360 - val_mean_squared_error: 173.6360
# Epoch 12/15
# 25/25 [==============================] - 2s 86ms/step - loss: 123.2603 - mean_squared_error: 123.2603 - val_loss: 166.4651 - val_mean_squared_error: 166.4651
# Epoch 13/15
# 25/25 [==============================] - 2s 81ms/step - loss: 124.8367 - mean_squared_error: 124.8367 - val_loss: 169.2997 - val_mean_squared_error: 169.2997
# Epoch 14/15
# 25/25 [==============================] - 2s 79ms/step - loss: 122.7338 - mean_squared_error: 122.7338 - val_loss: 173.6889 - val_mean_squared_error: 173.6889
# Epoch 15/15
# 25/25 [==============================] - 2s 81ms/step - loss: 123.2710 - mean_squared_error: 123.2710 - val_loss: 168.0511 - val_mean_squared_error: 168.0511

# %%
lr_plot(historyr3,'CNN radius 45 epochs: Loss and MSE')

# %%
#lets see what the whole learning curve would look like
historyr_45 = historyr.history['val_mean_squared_error']
historyr_45.extend(historyr2.history['val_mean_squared_error'])
historyr_45.extend(historyr3.history['val_mean_squared_error'])

# %%
plt.plot(list(range(45)),np.sqrt(historyr_45),'--o',color='purple')
plt.xlabel('Epochs',fontsize=12)
plt.ylabel('RMSE',fontsize=12)
plt.title('Validation RMSE of CNN-radius',fontsize=16)
plt.savefig('images/cnnr_45.png')

# %%
modelCNNr.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 108, 108, 6)       60
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 54, 54, 6)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 54, 54, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 12)        660
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 26, 26, 12)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 26, 26, 12)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8112)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                97356
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 98,089
# Trainable params: 98,089
# Non-trainable params: 0
# _________________________________________________________________
